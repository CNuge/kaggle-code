# %% [markdown]
# # Goal
#
# I wish to cleanup the datetime columns of this data, turning it into proper timeseries format. In doing this I also wanted to add new columns, labelling the day of the week that the incidents occurred on and whether or not the incidents occurred on holidays. The reason for this is that I wanted to test the hypotheses that the distribution of laser related incidents will not be equal across the days of the week, and that the frequency of incidents will differ on holidays. Before conducting these statistical analyses I needed to get the data into a more usable format.

# %% [markdown]
# ## set up workspace
# import modules, note the kaggle kernels lack the holidays module
# pip install holidays

# %%
from datetime import date, datetime
import calendar
import pandas as pd
from pandas import Series, DataFrame
import holidays

# %% [markdown]
# I merged all the .csv files into one, removing the 'Total' row for the bottom of each. This was done using unix commands:
#
# echo 'DATE,TIME (UTC),ACID,No. A/C,TYPE A/C,ALT,MAJOR CITY,COLOR,Injury Reported,CITY,STATE' > all_laser_dat.csv
#
# grep -v 'Total' *.csv >> all_laser_dat.csv

# %%
laser_dat = pd.read_csv('all_laser_dat.csv')
laser_dat.head()
# Out:
#         DATE TIME (UTC)     ACID  No. A/C TYPE A/C    ALT MAJOR CITY  COLOR  \
# 0  01-Jan-10        102     AIR1        1     HELO   2000        LEX  Green
# 1  01-Jan-10        403   ASA513        1     B737  10000        LAX  Green
# 2  01-Jan-10        246  EGF3002        1     E135   7000        LAX  Green
# 3  01-Jan-10        157  EGF3086        1     E135   7000        LAX  Green
# 4  01-Jan-10        258   JBU300        1     A320  12500        SLI  Green
#
#   Injury Reported          CITY       STATE
# 0              NO     Lexington    Kentucky
# 1              NO   Los Angeles  California
# 2              NO   Los Angeles  California
# 3              NO   Los Angeles  California
# 4              NO  Los Alamitos  California

# %% [markdown]
# with the dataframe built I removed the 4 rows that do not have a time associated with them

# %%
laser_dat = laser_dat[laser_dat['TIME (UTC)'] != 'UNKN']

# %% [markdown]
# ## Turn the dates to python datetime format
# using the time and the data columns, and a few intermediate steps

# %%
laser_dat['TIME (UTC)']

laser_dat['hour'] = laser_dat.apply(lambda x: x['TIME (UTC)'][:-2], axis=1)
laser_dat['min'] = laser_dat.apply(lambda x: x['TIME (UTC)'][-2:], axis=1)

laser_dat['min'].fillna(0, inplace=True)
laser_dat['hour'].fillna(0, inplace=True)

#account for lack of zeros
min_changed = []
for i in laser_dat['min']:
	if len(i) == 0:
		min_changed.append('00')
	elif len(i) == 1:
		min_changed.append('0'+i)
	else:
		min_changed.append(i)

hr_changed = []
for i in laser_dat['hour']:
	if len(i) == 0:
		hr_changed.append('00')
	elif len(i) == 1:
		hr_changed.append('0'+i)
	else:
		hr_changed.append(i)


laser_dat['min_adj'] = min_changed
laser_dat['hr_adj'] = hr_changed

laser_dat['time'] = laser_dat.apply(lambda x: '%s:%s:%s' % (x['DATE'] , x['hr_adj'],  x['min_adj'] ), axis=1)

laser_dat['date_time'] = laser_dat.apply(lambda x: datetime.strptime(x['time'], '%d-%b-%y:%H:%M'), axis=1)

#drop the making of datetime columns, except for the 'hour' column
laser_dat = laser_dat.drop(['time','hour','min', 'min_adj','TIME (UTC)','DATE'], axis=1)

# %% [markdown]
# ## Add a column with the day of the week
# This uses the calendar library to get the day of the week for each date in the df

# %%
laser_dat['day_of_week'] = laser_dat.apply(lambda x:  calendar.day_name[x['date_time'].weekday()] , axis = 1)

# %% [markdown]
# ## Add a column with holiday/no holidays
# This uses the holidays library

# %%
#get us holidays
us_holidays = holidays.UnitedStates()
#build the column
holiday_tf = []
for date in laser_dat['date_time']:
	if date in us_holidays:
		holiday_tf.append(True)
	elif date not in us_holidays:
		holiday_tf.append(False)


laser_dat['holidays'] = holiday_tf

# %%
laser_dat
# Out:
#            ACID  No. A/C             TYPE A/C    ALT MAJOR CITY   COLOR  \
# 0          AIR1        1                 HELO   2000        LEX   Green
# 1        ASA513        1                 B737  10000        LAX   Green
# 2       EGF3002        1                 E135   7000        LAX   Green
# 3       EGF3086        1                 E135   7000        LAX   Green
# 4        JBU300        1                 A320  12500        SLI   Green
# 5        JBU303        1                 A320   2000        LGB   Green
# 6           PD2        1                 E120    700        FAT   Green
# 7       SKW6083        1                 CRJ2   6800        LNK   Green
# 8       SKW6318        1                 E120   1000        LAX   Green
# 9       SKW6433        1                 CRJ2   1000        FAT   Green
# 10      SWA3652        1                 B737   3000        OAK   Green
# 11      BTA2194        1                 E145  36000        TBD   Green
# 12      ASH9421        1                 CRJ9   2500        PHX   Green
# 13      COA1671        1                 B733   1000        TUS   Green
# 14      DAL1298        1                 MD81   2000        PHL   Green
# 15      EGF2771        2                 E135   UNKN        VPS   Green
# 16      EGF4325        1                 E145    800        ORD   Green
# 17       FRT753        1                 A319   9000        LAX   Green
# 18        JEM94        1                 C750   3000        SGR   Green
# 19      SKW6430        1                 CRJ7   UNKN        SAT   Green
# 20      SSX3335        1                 DH8D  11000        ALB   Green
# 21      AAL1543        1                 MD81   5200        SJC     Red
# 22      BTA2901        1                 E45X  FL300        TBD   Green
# 23       N725BH        1                 PA31   3800        TUS   Green
# 24      SKW6284        1                 E120   1100        LAX   Green
# 25      SWA2542        1                 B737   5000        MZB   Green
# 26       AAL127        1                 MD81   3500        MZB   Green
# 27       N241CT        1                 WW24   1800        SJU   Green
# 28        N35WS        1                 C172   3000        CLT   Green
# 29         AIR1        1                B206B   3000        TUS  Green
# ...         ...      ...                  ...    ...        ...     ...
# 17657  LIFENET4        1    B407 (BELL - 407)   2000        OMA   Green
# 17658    NKS212        1                 A319   3000       2FL1    Blue
# 17659    UPS918        1                 A300      0        BUR   Green
# 17660   GJS3633        1  CRJ7 (CANADAIR - Ch   3000        ORD   Green
# 17661   ASQ5072        1                 CRJ9   2000        ABE   Green
# 17662    QAI504        1                 CVLP   3000        OPR   Green
# 17663   UPS9610        1  B752 (BOEING - 757-   2500        LAN   White
# 17664   JBU1233        1  E190 (EMBRAER - 190   3000        SJU   Green
# 17665    ASA528        1  B738 (BOEING - 737-   2600        VNY   Green
# 17666   WBR2709        1   C208 (CESSNA - 208   6000        FES   Green
# 17667    VRD878        1  A319 (AIRBUS - A-31   6000        DCA   Green
# 17668    AAY795        1  MD83 (BOEING - MD-8   1500        SFB   Green
# 17669   DAL1549        1                 MD88   1600        DAB   Green
# 17670   ASQ950T        1  E45X (EMBRAER - EMB   UNKN        TUL   Green
# 17671    RCH291        1   C17 (BOEING - C-17   2000        WRI   Green
# 17672    SWA240        1                 B737   7600        BOS   Green
# 17673   CPZ5817        1  E170 (EMBRAER - 170   6000        SFO   Green
# 17674    CPA872        1  B77W (Boeing - 777-   4000        SFO   Green
# 17675   SKW5402        1  E120 (EMBRAER - Bra   6000        SFO   Green
# 17686              NO                 Miami               Florida     23
#
#                 date_time day_of_week  holidays
# 0     2010-01-01 01:02:00      Friday      True
# 1     2010-01-01 04:03:00      Friday      True
# 2     2010-01-01 02:46:00      Friday      True
# 3     2010-01-01 01:57:00      Friday      True
# 4     2010-01-01 02:58:00      Friday      True
# 5     2010-01-01 02:55:00      Friday      True
# 6     2010-01-01 08:57:00      Friday      True
# 7     2010-01-01 00:44:00      Friday      True
# 8     2010-01-01 01:55:00      Friday      True
# 9     2010-01-01 07:30:00      Friday      True
# 10    2010-01-01 03:02:00      Friday      True
# 11    2010-01-02 02:44:00    Saturday     False
# 12    2010-01-03 08:22:00      Sunday     False
# 13    2010-01-03 02:31:00      Sunday     False
# 14    2010-01-03 05:18:00      Sunday     False
# 15    2010-01-03 00:00:00      Sunday     False
# 16    2010-01-03 02:07:00      Sunday     False
# 17    2010-01-03 08:28:00      Sunday     False
# 18    2010-01-03 03:15:00      Sunday     False
# 19    2010-01-03 06:06:00      Sunday     False
# 20    2010-01-04 05:20:00      Monday     False
# 21    2010-01-05 03:09:00     Tuesday     False
# 22    2010-01-05 00:49:00     Tuesday     False
# 23    2010-01-05 03:41:00     Tuesday     False
# 24    2010-01-05 07:00:00     Tuesday     False
# 25    2010-01-05 02:26:00     Tuesday     False
# 26    2010-01-06 03:50:00   Wednesday     False
# 27    2010-01-06 01:53:00   Wednesday     False
# 28    2010-01-06 01:17:00   Wednesday     False
# 29    2010-01-06 03:46:00   Wednesday     False
# ...                   ...         ...       ...
# 17657 2014-12-29 00:07:00      Monday     False
# 17658 2014-12-29 00:40:00      Monday     False
# 17659 2014-12-29 02:09:00      Monday     False
# 17660 2014-12-29 02:42:00      Monday     False
# 17661 2014-12-29 03:30:00      Monday     False
# 17662 2014-12-29 23:45:00      Monday     False
# 17663 2014-12-30 01:30:00     Tuesday     False
# 17664 2014-12-30 01:40:00     Tuesday     False
# 17665 2014-12-30 01:58:00     Tuesday     False
# 17666 2014-12-30 01:58:00     Tuesday     False
# 17667 2014-12-30 02:05:00     Tuesday     False
# 17668 2014-12-30 02:46:00     Tuesday     False
# 17669 2014-12-30 03:00:00     Tuesday     False
# 17670 2014-12-30 03:05:00     Tuesday     False
# 17671 2014-12-30 03:05:00     Tuesday     False
# 17672 2014-12-30 04:32:00     Tuesday     False
# 17673 2014-12-30 04:50:00     Tuesday     False
# 17674 2014-12-30 04:51:00     Tuesday     False
# 17675 2014-12-30 04:52:00     Tuesday     False
# 17676 2014-12-30 04:54:00     Tuesday     False
# 17677 2014-12-30 08:16:00     Tuesday     False
# 17678 2014-12-30 17:37:00     Tuesday     False
# 17679 2014-12-31 00:14:00   Wednesday     False
# 17680 2014-12-31 00:46:00   Wednesday     False
# 17681 2014-12-31 03:50:00   Wednesday     False
# 17682 2014-12-31 04:43:00   Wednesday     False
# 17683 2014-12-31 04:45:00   Wednesday     False
# 17684 2014-12-31 04:45:00   Wednesday     False
# 17685 2014-12-31 05:15:00   Wednesday     False
# 17686 2014-12-31 23:44:00   Wednesday     False
#
# [17683 rows x 13 columns]

# %% [markdown]
# Now the data has a column with the data in python datetime format, as well as two additional columns 'day_of_week' and 'holidays' which I will use for visualization and statistics.

# %%
laser_dat.to_csv('adjusted_laser_data.csv')
